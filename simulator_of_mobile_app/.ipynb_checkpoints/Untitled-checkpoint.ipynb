# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv', names=['error_code', 'error_message', 'severity', 'log_location', 'mode', 'model', 'graphics', 'session_id', 'sdkv', 'test_mode', 'flow_id', 'flow_type', 'sdk_date', 'publisher_id', 'game_id', 'bundle_id', 'appv', 'language', 'os', 'adv_id', 'gdpr', 'ccpa', 'country_code', 'date'])[1:]
data['date'] = pd.to_datetime(data['date'], unit='s')
data.sort_values(by="date")
# Out:
# /tmp/ipykernel_56230/2827093931.py:1: DtypeWarning: Columns (9,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data.csv', names=['error_code', 'error_message', 'severity', 'log_location', 'mode', 'model', 'graphics', 'session_id', 'sdkv', 'test_mode', 'flow_id', 'flow_type', 'sdk_date', 'publisher_id', 'game_id', 'bundle_id', 'appv', 'language', 'os', 'adv_id', 'gdpr', 'ccpa', 'country_code', 'date'])[1:]
#          error_code                                      error_message  \
# 834027            0        An error occurred while sending the request
# 834028            0             could not receive ip address from ipfy
# 834029            0             could not receive ip address from ipfy
# 834030            0        An error occurred while sending the request
# 834031            0  We are running "Programmatic Flow", you need t...
# ...             ...                                                ...
# 1083870           0             could not receive ip address from ipfy
# 1083871           0             could not receive ip address from ipfy
# 1083872           0        An error occurred while sending the request
# 1083873           0             could not receive ip address from ipfy
# 1083874           0        An error occurred while sending the request
#
#         severity    log_location       mode             model   graphics  \
# 834027     Error  /BuildNotice/0  MobileSDK  samsung SM-A125F  OpenGLES2
# 834028     Error  /BuildNotice/0  MobileSDK  samsung SM-A125F  OpenGLES2
# 834029     Error  /BuildNotice/0  MobileSDK  samsung SM-A125F  OpenGLES2
# 834030     Error  /BuildNotice/0  MobileSDK  samsung SM-A125F  OpenGLES2
# 834031     Error  /BuildNotice/0  MobileSDK    HUAWEI DUB-LX3  OpenGLES2
# ...          ...             ...        ...               ...        ...
# 1083870    Error  /BuildNotice/0  MobileSDK  samsung SM-J260F  OpenGLES2
# 1083871    Error  /BuildNotice/0  MobileSDK    HUAWEI STK-LX3  OpenGLES2
# 1083872    Error  /BuildNotice/0  MobileSDK    HUAWEI STK-LX3  OpenGLES2
# 1083873    Error  /BuildNotice/0  MobileSDK  samsung SM-J260F  OpenGLES2
# 1083874    Error  /BuildNotice/0  MobileSDK  samsung SM-J260F  OpenGLES2
#
#          session_id    sdkv test_mode  ...                   game_id  \
# 834027          1.0  1.10.2     False  ...  611be843d5491c7d0a6ab0ce
# 834028          1.0  1.10.2     False  ...  611be843d5491c7d0a6ab0ce
# 834029          1.0  1.10.2     False  ...  611be843d5491c7d0a6ab0ce
# 834030          1.0  1.10.2     False  ...  611be843d5491c7d0a6ab0ce
# 834031          1.0  1.10.2     False  ...  611be843d5491c7d0a6ab0ce
# ...             ...     ...       ...  ...                       ...
# 1083870         1.0  1.11.0     False  ...  609d69021c511f4b1d4df1c4
# 1083871         1.0  1.11.0     False  ...  6028e407a1ba2a0d3d760566
# 1083872         1.0  1.11.0     False  ...  6028e407a1ba2a0d3d760566
# 1083873         1.0  1.11.0     False  ...  609d69021c511f4b1d4df1c4
# 1083874         1.0  1.11.0     False  ...  609d69021c511f4b1d4df1c4
#
#                                    bundle_id appv language  \
# 834027       com.thg.battleops.shooting.game  1.0       iv
# 834028       com.thg.battleops.shooting.game  1.0       iv
# 834029       com.thg.battleops.shooting.game  1.0       iv
# 834030       com.thg.battleops.shooting.game  1.0       iv
# 834031       com.thg.battleops.shooting.game  1.0       iv
# ...                                      ...  ...      ...
# 1083870       com.pregnantcatemma.virtualpet  1.0       iv
# 1083871  com.mytalkingcatemma.ballerinagames  1.0       es
# 1083872  com.mytalkingcatemma.ballerinagames  1.0       es
# 1083873       com.pregnantcatemma.virtualpet  1.0       iv
# 1083874       com.pregnantcatemma.virtualpet  1.0       iv
#
#                                                         os  \
# 834027   Android OS 11 / API-30 (RP1A.200720.012/A125FX...
# 834028   Android OS 11 / API-30 (RP1A.200720.012/A125FX...
# 834029   Android OS 11 / API-30 (RP1A.200720.012/A125FX...
# 834030   Android OS 11 / API-30 (RP1A.200720.012/A125FX...
# 834031   Android OS 8.1.0 / API-27 (HUAWEIDUB-LX3/163(C...
# ...                                                    ...
# 1083870    Android OS 8.1.0 / API-27 (M1AJB/J260FXXU9AUD3)
# 1083871  Android OS 9 / API-28 (HUAWEISTK-LX3/9.1.0.223...
# 1083872  Android OS 9 / API-28 (HUAWEISTK-LX3/9.1.0.223...
# 1083873    Android OS 8.1.0 / API-27 (M1AJB/J260FXXU9AUD3)
# 1083874    Android OS 8.1.0 / API-27 (M1AJB/J260FXXU9AUD3)
#
#                                        adv_id   gdpr   ccpa country_code  \
# 834027   5e5e4f04-db8f-45ac-83b4-b62c451c51e5   True  False           BR
# 834028   5e5e4f04-db8f-45ac-83b4-b62c451c51e5   True  False           BR
# 834029   5e5e4f04-db8f-45ac-83b4-b62c451c51e5   True  False           BR
# 834030   5e5e4f04-db8f-45ac-83b4-b62c451c51e5   True  False           BR
# 834031   3a9d8d4c-f1b0-42b7-bcd9-ec15eea58c37   True  False           CR
# ...                                       ...    ...    ...          ...
# 1083870  68fba541-ca66-4a1b-87f4-558db30303bb  False  False           RU
# 1083871  972f0bea-74ec-44c9-b845-3c635f01ff5b  False  False           IQ
# 1083872  972f0bea-74ec-44c9-b845-3c635f01ff5b  False  False           IQ
# 1083873  68fba541-ca66-4a1b-87f4-558db30303bb  False  False           RU
# 1083874  68fba541-ca66-4a1b-87f4-558db30303bb  False  False           RU
#
#                                  date
# 834027  2021-09-11 00:00:47.224421888
# 834028  2021-09-11 00:00:47.390925056
# 834029  2021-09-11 00:00:48.054912000
# 834030  2021-09-11 00:00:48.085171968
# 834031  2021-09-11 00:00:49.264563200
# ...                               ...
# 1083870 2021-09-14 23:59:45.804591872
# 1083871 2021-09-14 23:59:49.702807808
# 1083872 2021-09-14 23:59:49.779883008
# 1083873 2021-09-15 00:00:01.686283008
# 1083874 2021-09-15 00:00:02.602370048
#
# [1506152 rows x 24 columns]

# %%
data = pd.read_csv('data.csv', names=['error_code', 'error_message', 'severity', 'log_location', 'mode', 'model', 'graphics', 'session_id', 'sdkv', 'test_mode', 'flow_id', 'flow_type', 'sdk_date', 'publisher_id', 'game_id', 'bundle_id', 'appv', 'language', 'os', 'adv_id', 'gdpr', 'ccpa', 'country_code', 'date']).sort_values('date').iloc[1:10000]

(data.sort_values('date', ascending=False)['date'].iloc[0] - data.sort_values('date')['date'].iloc[0]) / 3600
# Out:
# /tmp/ipykernel_56230/2977577006.py:1: DtypeWarning: Columns (9,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('data.csv', names=['error_code', 'error_message', 'severity', 'log_location', 'mode', 'model', 'graphics', 'session_id', 'sdkv', 'test_mode', 'flow_id', 'flow_type', 'sdk_date', 'publisher_id', 'game_id', 'bundle_id', 'appv', 'language', 'os', 'adv_id', 'gdpr', 'ccpa', 'country_code', 'date']).sort_values('date').iloc[1:10000]
# 1.2305520239141252

# %%
data.sort_values('date', ascending=False)['date'].iloc[0], data.shape
# Out:
# (Timestamp('2021-09-11 01:14:37.211708160'), (2000, 24))

# %%
data.sort_values('date')['date'].iloc[0]
# Out:
# Timestamp('2021-09-11 01:03:51.859065088')
